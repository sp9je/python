# %%
# 덧셈 (+)
result = 10 + 5
print(result)  # 15

# 뺄셈 (-)
result = 10 - 5
print(result)  # 5

# 곱셈 (*)
result = 10 * 5
print(result)  # 50

# 나눗셈 (/)
result = 10 / 3
print(result)  # 3.3333333333333335 (항상 실수 반환)
# Out:
# 15
# 5
# 50
# 3.3333333333333335

# %%
# 쇼핑몰 할인 계산 프로그램
print("=== 쇼핑몰 할인 계산기 ===")

# 상품 정보 입력
original_price = int(input("원가를 입력하세요: "))
discount_rate = int(input("할인율을 입력하세요 (예: 20): "))

# 할인 금액 계산
discount_amount = original_price * discount_rate / 100

# 최종 가격 계산
final_price = original_price - discount_amount

# 결과 출력
print(f"\n원가: {original_price:,}원")
print(f"할인율: {discount_rate}%")
print(f"할인 금액: {discount_amount:,.0f}원")
print(f"최종 가격: {final_price:,.0f}원")
# Out:
# === 쇼핑몰 할인 계산기 ===

# %%
# 나이 확인 프로그램
print("=== 나이 확인 시스템 ===")

age = int(input("나이를 입력하세요: "))

# 성인 여부 확인
is_adult = age >= 18

print(f"\n입력하신 나이: {age}세")
print(f"성인 여부: {is_adult}")

# 아직 배우지 않은 조건문이지만    
if is_adult:
    print("성인입니다. 모든 콘텐츠에 접근할 수 있습니다.")
else:
    print("미성년자입니다. 일부 콘텐츠가 제한됩니다.")
# Out:
# === 나이 확인 시스템 ===
#
# 입력하신 나이: 21세
# 성인 여부: True
# 성인입니다. 모든 콘텐츠에 접근할 수 있습니다.

# %%
# 점수 누적 계산
total_score = 0
total_score += 85  # 첫 번째 시험
total_score += 90  # 두 번째 시험
total_score += 88  # 세 번째 시험
print(f"총점: {total_score}")  # 263

# 카운터 증가
count = 0
count += 1  # 1 증가
count += 1  # 1 증가
count += 1  # 1 증가
print(f"카운트: {count}")  # 3
# Out:
# 총점: 263
# 카운트: 3

# %%
# 게임 점수 계산 프로그램
print("=== 게임 점수 시스템 ===")

# 초기값 설정
score = 0
level = 1

# 게임 진행
print("스테이지 1 클리어!")
score += 100
print(f"현재 점수: {score}")

print("\n보너스 아이템 획득!")
score *= 2  # 점수 2배
print(f"현재 점수: {score}")

print("\n스테이지 2 클리어!")
score += 150
print(f"현재 점수: {score}")

# 레벨업 조건 확인 (300점 이상)
if score >= 300:
    level += 1
    print(f"\n레벨업! 현재 레벨: {level}")

print(f"\n최종 점수: {score}")
print(f"최종 레벨: {level}")
# Out:
# === 게임 점수 시스템 ===
# 스테이지 1 클리어!
# 현재 점수: 100
#
# 보너스 아이템 획득!
# 현재 점수: 200
#
# 스테이지 2 클리어!
# 현재 점수: 350
#
# 레벨업! 현재 레벨: 2
#
# 최종 점수: 350
# 최종 레벨: 2

# %%
# 복잡한 계산 - 평균 구하기
korean = 85
english = 90
math = 88

# 잘못된 방법 (우선순위 문제)
average = korean + english + math / 3  # 88/3을 먼저 계산
print(average)  # 204.33333... (잘못된 결과)

# 올바른 방법
average = (korean + english + math) / 3
print(average)  # 87.66666... (올바른 결과)

# %%
school_name = "영남이공대학교 "
my_name = "김동현"

profile = "대학: " + school_name + "성명: " my_name

print(profile, "1학년")
# Out:
#   Cell In[2], line 4
#     profile = "대학: " + school_name + "성명: " my_name
#                                             ^
# SyntaxError: invalid syntax

# %%
cola = 1000
cnt = 2

total = cola * cnt
result = "콜라 " + str(cnt) + "개 가격은 " + str(total) + "원 입니다."
print(total)
# Out:
# 2000

# %%
a = 4
b = 5
c = "nice !"
print(a * b)
print(a * c)

# %%
print("-" * 50)
print("주문서")
print("-" * 50)
# Out:
# --------------------------------------------------
# 주문서
# --------------------------------------------------

# %%
# 영수증 출력 프로그램
print("=== 영수증 생성기 ===")

# 상점 정보
store_name = "파이썬 마트"
store_address = "서울시 강남구 파이썬로 123"

# 구매 정보 입력
product_name = input("상품명: ")
unit_price = int(input("단가: "))
quantity = int(input("수량: "))

# 계산
total_price = unit_price * quantity

# 영수증 출력
line = "=" * 40
print("\n" + line)
print(store_name.center(40))  # 중앙 정렬
print(store_address.center(40))
print(line)
print("상품명".ljust(20) + "수량".rjust(10) + "금액".rjust(10))
print(line)
print(product_name.ljust(20) + str(quantity).rjust(10) + f"{unit_price:,}원".rjust(10))
print(line)
print("합계".ljust(30) + f"{total_price:,}원".rjust(10))
print(line)
print("\n감사합니다!".center(40))
print(line)
# Out:
# === 영수증 생성기 ===
#
# ========================================
#                  파이썬 마트
#             서울시 강남구 파이썬로 123
# ========================================
# 상품명                         수량        금액
# ========================================
# 커피                           5    1,800원
# ========================================
# 합계                                9,000원
# ========================================
#
# 감사합니다!
# ========================================

# %%
# 힌트
hourly_wage = int(input("시급: "))
regular_hours = int(input("일반 근무 시간: "))
night_hours = int(input("야간 근무 시간: "))
duty = int(input("세금: "))

# 여기에 계산 코드를 작성하세요
# 일반 근무 급여 = 시급 * 일반 근무 시간
income_regular = hourly_wage * regular_hours
# 야간 근무 급여 = 시급 * 1.5 * 야간 근무 시간
income_night = hourly_wage * 1.5 * night_hours
# 총 급여 = 일반 근무 급여 + 야간 근무 급여
income_total = income_regular + income_night
# 세금
income_duty = (duty / 100) * income_total
# 실수령액
actual_salary = income_total - income_duty

print("=" * 30)
print("급여명세서".center(30))
print("=" * 30)
print("시급 : ", hourly_wage)
print("주간근무시간 : ", regular_hours, "주간급여 :", income_regular)
print("야간근무시간 : ", night_hours, "야간급여 :", income_night)
print("총급여 : ", income_total)
print("=" * 30)
print("세금 : ", income_duty)
print("실수령액 :", actual_salary)
# Out:
# ==============================
#             급여명세서
# ==============================
# 시급 :  10000
# 주간근무시간 :  10 주간급여 : 100000
# 야간근무시간 :  10 야간급여 : 150000.0
# 총급여 :  250000.0
# ==============================
# 세금 :  20000.0
# 실수령액 : 230000.0

# %%
# 힌트
year = int(input("연도를 입력하세요: "))

# 윤년 조건 확인
is_leap_year = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

print(f"{year}년은 윤년입니까? {is_leap_year}")
# Out:
# 2026년은 윤년입니까? False
